# %%
import json

taxonomy_data = {
  "issue_types": [
    "character_continuity",
    "prop_continuity",
    "wardrobe_continuity",
    "time_of_day_inconsistency",
    "location_inconsistency",
    "chronology_inconsistency"
  ]
}

with open("taxonomy.json", "w") as outFile:
    json.dump(taxonomy_data, outFile, indent=2)
