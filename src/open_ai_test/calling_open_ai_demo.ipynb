# %%
from openai import OpenAI

client = OpenAI()

response = client.responses.create(
    model="gpt-4.1",
    input="Explain what a script supervisor does in movie production."
)

print(response.output[0].content[0].text)
# Out:
# A **script supervisor** (also known as a continuity supervisor) is a vital crew member on a movie or television set, responsible for ensuring continuity throughout the filming process.
#
# **Key duties of a script supervisor include:**
#
# 1. **Continuity:**
#    - Tracking the consistency of the story, actions, props, costumes, makeup, and positions of actors from shot to shot and scene to scene.
#    - Noting details like the exact position of objects, what hand an actor uses for a gesture, or how much food is left on a plate after multiple takes.
#
# 2. **Script Tracking:**
#    - Marking the screenplay as it is filmed, keeping notes on which parts of the script have been shot and which haven’t.
#    - Ensuring dialogue is delivered as written, unless changes are approved by the director or writer.
#
# 3. **Production Notes:**
#    - Documenting each take, including technical details (such as lens used, shot description, slate numbers, and any problems or suggestions for editing).
#    - Creating a “continuity log” or “lined script” for the editor, indicating which takes are “circled” (the director’s preferred takes).
#
# 4. **Timing:**
#    - Timing scenes as they are shot, which helps estimate the final length of the movie.
#
# 5. **Liaison Work:**
#    - Communicating with the director, actors, camera department, costume, makeup, props, and other departments to resolve continuity issues or discrepancies as they arise.
#
# **In summary:**
# The script supervisor acts as the guardian of continuity and detail, helping to ensure that the finished film is smooth, coherent, and error-free, despite being filmed out of sequence and over weeks or months. Their meticulous records and attention prevent the audience from noticing mistakes that might distract from the story.

# %%
from openai import OpenAI
import json

client = OpenAI()

prompt = """
Extract the following from this script:

- Scene heading
- Location
- Time of day
- Characters present

Return JSON only.

Script:
INT. COFFEE SHOP - MORNING
John sits alone. Sarah enters.
"""

'''
response = client.responses.create(
    model="gpt-4.1",
    input=prompt,
    response_format={"type": "json_object"}
)
'''
response = client.chat.completions.create(
    model="gpt-4.1",
    messages=[{"role": "user", "content": prompt}],
    response_format={"type": "json_object"}
)

#data = json.loads(response.output_text)
data = json.loads(response.choices[0].message.content)
print(data)
# Out:
# {'scene_heading': 'INT. COFFEE SHOP - MORNING', 'location': 'COFFEE SHOP', 'time_of_day': 'MORNING', 'characters_present': ['John', 'Sarah']}
