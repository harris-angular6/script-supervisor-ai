# %%
import json
from pathlib import Path

path = Path("datasets/scenes/train_scenes.jsonl")

with path.open("r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        row = json.loads(line)
        print(json.dumps(row, indent=2, ensure_ascii=False))
        print("-" * 80)
        if i >= 2:
            break
# Out:
# {
#   "script_id": "synthetic_script_0010",
#   "scene_id": "synthetic_script_0010_scene_01",
#   "scene_index": 1,
#   "slugline": "EXT. BUSY STREET - DAY",
#   "location": "BUSY STREET",
#   "time_of_day": "DAY",
#   "scene_text": "A crowd of people scurry down the sidewalk, passing by JEN, a 35-year-old woman, who leans against a lamppost, staring at her phone with a disheartened expression.\nJEN\n(whispering to herself)\nOne more rejection...\nSuddenly, her phone beeps. She looks up, hopeful.",
#   "characters": [
#     "JEN"
#   ],
#   "props": [
#     "phone"
#   ],
#   "actions": [
#     "A crowd of people scurry down the sidewalk, passing by JEN, a 35-year-old woman, who leans against a lamppost, staring at her phone with a disheartened expression.",
#     "Suddenly, her phone beeps. She looks up, hopeful."
#   ]
# }
# --------------------------------------------------------------------------------
# {
#   "script_id": "synthetic_script_0010",
# ...
