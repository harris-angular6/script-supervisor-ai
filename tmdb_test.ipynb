# %%
import requests


TOKEN = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyZjE0Mzk5ZDFmMGQ0ZWIyM2U3NDIxNWEwZTMyNTVmOSIsIm5iZiI6MTc4MDg4NDEyNy4wMjksInN1YiI6IjZhMjYyMjlmODYzYzdkMDc2MjllOWNkZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.G_vdAzJdRpooSnj39IjAmbZPcicdCky9leukEmLirdc"


headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {TOKEN}"
}


url = "https://api.themoviedb.org/3/person/popular"


params = {
    "language": "en-US",
    "page": 3
}


response = requests.get(
    url,
    headers=headers,
    params=params
)


data = response.json()


for person in data["results"]:

    if person["known_for_department"] == "Acting":

        print("----------------")
        print("ID:", person["id"])
        print("Name:", person["name"])
        print("Popularity:", person["popularity"])
        print("Photo:", person["profile_path"])
# Out:
# ----------------
# ID: 555955
# Name: Rieko Miura
# Popularity: 9.6563
# Photo: /339LlgMPlxorzvM6iKUvwOPHLwh.jpg
# ----------------
# ID: 3186373
# Name: Cha Woo-min
# Popularity: 9.6208
# Photo: /ixVqsa3izvBbWbwz8Isd4sjuTUm.jpg
# ----------------
# ID: 5081
# Name: Emily Blunt
# Popularity: 9.5026
# Photo: /5nCSG5TL1bP1geD8aaBfaLnLLCD.jpg
# ----------------
# ID: 2065258
# Name: Cemre Baysel
# Popularity: 9.4957
# Photo: /c6ftdtt8o8NCp5o8v7rJmmhlQ3C.jpg
# ----------------
# ID: 3164807
# Name: Yoon Yool
# Popularity: 9.3644
# Photo: /21kdujBeL2hrJ50RyMxmuEsHZAT.jpg
# ----------------
# ID: 1813
# Name: Anne Hathaway
# Popularity: 9.1665
# Photo: /nbccV2pMoyLTCeg5DQip24Eq0Jp.jpg
# ----------------
# ID: 2553248
# Name: Angela Giarratana
# Popularity: 9.1124
# Photo: /4zaXSQ6cP45zBv5Ngb9SfudEZS4.jpg
# ----------------
# ID: 83487
# Name: Xie Miao
# Popularity: 9.0773
# Photo: /o6uRkrY9vxxzZkZGnnQtKLPcZH1.jpg
# ----------------
# ID: 1831272
# Name: Moemi Katayama
# Popularity: 8.906
# ...

# %%
import requests


TOKEN = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyZjE0Mzk5ZDFmMGQ0ZWIyM2U3NDIxNWEwZTMyNTVmOSIsIm5iZiI6MTc4MDg4NDEyNy4wMjksInN1YiI6IjZhMjYyMjlmODYzYzdkMDc2MjllOWNkZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.G_vdAzJdRpooSnj39IjAmbZPcicdCky9leukEmLirdc"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {TOKEN}"
}


actor_id = 224513   # Emma Stone


url = (
    f"https://api.themoviedb.org/3/person/"
    f"{actor_id}"
)


response = requests.get(
    url,
    headers=headers
)


actor = response.json()


print(actor["name"])
print(actor["birthday"])
print(actor["place_of_birth"])
print(actor["biography"])
# Out:
# Ana de Armas
# 1988-04-30
# Santa Cruz del Norte, Cuba
# Ana Celia de Armas Caso (born 30 April 1988) is a Cuban-Spanish actress. She began her career in Cuba at age 16 with a leading role in the romantic crime drama Virgin Rose (2006). At 18 she obtained her Spanish passport through her maternal grandparents, which allowed her to legally relocate to Spain to pursue acting. She moved to Madrid and starred in the popular drama El Internado (2007–2010). In 2014, she moved to Los Angeles and secured English-speaking roles in the psychological thriller Knock Knock (2015) and the comedy-crime film War Dogs (2016).
#
# ...

# %%
image_base = "https://image.tmdb.org/t/p/w500"

photo_url = image_base + actor["profile_path"]

print(photo_url)
# Out:
# https://image.tmdb.org/t/p/w500/tkBWBvcLTihUcVf6iwbMQTFqEEv.jpg

# %%
from IPython.display import Image, display, Markdown

actor = {
    #"name": "Emma Stone",
    "name": actor["name"],
    "birthday": "1988-11-06",
    "biography": "American actress...",
    "photo_url": "https://image.tmdb.org/t/p/w500/tkBWBvcLTihUcVf6iwbMQTFqEEv.jpg"
}


display(Image(url=actor["photo_url"]))

display(
    Markdown(
        f"""
# {actor["name"]}

**Birthday:** {actor["birthday"]}

**Biography:**

{actor["biography"]}
"""
    )
)
# Out:
# <img src="https://image.tmdb.org/t/p/w500/tkBWBvcLTihUcVf6iwbMQTFqEEv.jpg"/>
# # Ana de Armas
#
# **Birthday:** 1988-11-06
#
# **Biography:**
#
# American actress...
